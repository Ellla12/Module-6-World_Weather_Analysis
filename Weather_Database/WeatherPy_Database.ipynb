# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=aec7eb97e17c882881cb2e31d4a264ff

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Generate 2,000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

     # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        weather_description = city_weather["weather"][0]["description"]
        
        try:
            rain_inches = city_weather["rain"]["3h"]
        except:
            rain_inches = ("0")
            pass
        try:
            snow_inches = city_weather["snow"]["3h"]
        except:
            snow_inches = ("0")  
            pass
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | saskylakh
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | ahuimanu
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | umm jarr
# City not found. Skipping...
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | poros
# Processing Record 15 of Set 1 | troitsko-pechorsk
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | chokurdakh
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | santa rosalia
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | rosarito
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | filingue
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | kurilsk
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | baoro
# Processing Record 39 of Set 1 | gigmoto
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | talnakh
# Processing Record 42 of Set 1 | palmerston
# Processing Record 43 of Set 1 | panaba
# Processing Record 44 of Set 1 | vila franca do campo
# Processing Record 45 of Set 1 | richards bay
# Processing Record 46 of Set 1 | palmer
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | cayenne
# Processing Record 50 of Set 1 | olinda
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | cabadiangan
# Processing Record 3 of Set 2 | itaituba
# Processing Record 4 of Set 2 | teixeira
# Processing Record 5 of Set 2 | tshikapa
# Processing Record 6 of Set 2 | salas
# Processing Record 7 of Set 2 | cururupu
# Processing Record 8 of Set 2 | saint-pierre
# Processing Record 9 of Set 2 | katunki
# City not found. Skipping...
# Processing Record 10 of Set 2 | pisco
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | goderich
# Processing Record 13 of Set 2 | tilichiki
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | lubbock
# Processing Record 16 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 2 | canico
# Processing Record 19 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 2 | meadow lake
# Processing Record 22 of Set 2 | terre haute
# Processing Record 23 of Set 2 | provideniya
# Processing Record 24 of Set 2 | namatanai
# Processing Record 25 of Set 2 | velingrad
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | quatre cocos
# Processing Record 28 of Set 2 | bemidji
# Processing Record 29 of Set 2 | otane
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | tangzhai
# Processing Record 33 of Set 2 | chingola
# Processing Record 34 of Set 2 | fallon
# Processing Record 35 of Set 2 | grindavik
# Processing Record 36 of Set 2 | carbonia
# Processing Record 37 of Set 2 | biltine
# Processing Record 38 of Set 2 | husavik
# Processing Record 39 of Set 2 | mildura
# Processing Record 40 of Set 2 | umba
# Processing Record 41 of Set 2 | kommunar
# Processing Record 42 of Set 2 | tateyama
# Processing Record 43 of Set 2 | hasaki
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | vardo
# Processing Record 46 of Set 2 | agirish
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | onega
# Processing Record 49 of Set 2 | constitucion
# Processing Record 50 of Set 2 | longyearbyen
# Processing Record 1 of Set 3 | rikitea
# Processing Record 2 of Set 3 | poum
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | broome
# Processing Record 5 of Set 3 | borujan
# City not found. Skipping...
# Processing Record 6 of Set 3 | yulara
# Processing Record 7 of Set 3 | sao filipe
# Processing Record 8 of Set 3 | kasongo-lunda
# Processing Record 9 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 3 | balsas
# Processing Record 11 of Set 3 | hearst
# Processing Record 12 of Set 3 | wampusirpi
# City not found. Skipping...
# Processing Record 13 of Set 3 | kristianstad
# Processing Record 14 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | lieksa
# Processing Record 17 of Set 3 | baiyin
# Processing Record 18 of Set 3 | saint-philippe
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | huarmey
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | gasa
# Processing Record 23 of Set 3 | liverpool
# Processing Record 24 of Set 3 | kavaratti
# Processing Record 25 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 3 | skjervoy
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | keti bandar
# Processing Record 30 of Set 3 | qaqortoq
# Processing Record 31 of Set 3 | port augusta
# Processing Record 32 of Set 3 | staryy nadym
# Processing Record 33 of Set 3 | atasu
# Processing Record 34 of Set 3 | meulaboh
# Processing Record 35 of Set 3 | vanavara
# Processing Record 36 of Set 3 | sorland
# Processing Record 37 of Set 3 | sobolevo
# Processing Record 38 of Set 3 | luderitz
# Processing Record 39 of Set 3 | nkowakowa
# Processing Record 40 of Set 3 | yangambi
# Processing Record 41 of Set 3 | batangafo
# Processing Record 42 of Set 3 | manado
# Processing Record 43 of Set 3 | isangel
# Processing Record 44 of Set 3 | fare
# Processing Record 45 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 3 | shimoda
# Processing Record 47 of Set 3 | le port
# Processing Record 48 of Set 3 | norman wells
# Processing Record 49 of Set 3 | tomatlan
# Processing Record 50 of Set 3 | campobasso
# Processing Record 1 of Set 4 | zheleznodorozhnyy
# Processing Record 2 of Set 4 | khingansk
# Processing Record 3 of Set 4 | krasnaya poyma
# Processing Record 4 of Set 4 | kijang
# Processing Record 5 of Set 4 | kawalu
# Processing Record 6 of Set 4 | hamilton
# Processing Record 7 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 4 | dong hoi
# Processing Record 9 of Set 4 | bara
# Processing Record 10 of Set 4 | rio cuarto
# Processing Record 11 of Set 4 | carnarvon
# Processing Record 12 of Set 4 | alice springs
# Processing Record 13 of Set 4 | hithadhoo
# Processing Record 14 of Set 4 | hwange
# Processing Record 15 of Set 4 | obeliai
# Processing Record 16 of Set 4 | ruteng
# Processing Record 17 of Set 4 | champerico
# Processing Record 18 of Set 4 | abancay
# Processing Record 19 of Set 4 | ayer itam
# City not found. Skipping...
# Processing Record 20 of Set 4 | kodiak
# Processing Record 21 of Set 4 | abashiri
# Processing Record 22 of Set 4 | murray bridge
# Processing Record 23 of Set 4 | nabire
# Processing Record 24 of Set 4 | roald
# Processing Record 25 of Set 4 | puerto el triunfo
# Processing Record 26 of Set 4 | berlevag
# Processing Record 27 of Set 4 | avarua
# Processing Record 28 of Set 4 | hami
# Processing Record 29 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 30 of Set 4 | georgetown
# Processing Record 31 of Set 4 | ipixuna
# Processing Record 32 of Set 4 | mahibadhoo
# Processing Record 33 of Set 4 | fairbanks
# Processing Record 34 of Set 4 | galesburg
# Processing Record 35 of Set 4 | seelze
# Processing Record 36 of Set 4 | saint paul
# Processing Record 37 of Set 4 | saint anthony
# Processing Record 38 of Set 4 | saint george
# Processing Record 39 of Set 4 | usinsk
# Processing Record 40 of Set 4 | bengkulu
# Processing Record 41 of Set 4 | necochea
# Processing Record 42 of Set 4 | nsoko
# Processing Record 43 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 4 | touros
# Processing Record 45 of Set 4 | sherman
# Processing Record 46 of Set 4 | kirakira
# Processing Record 47 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 48 of Set 4 | chapais
# Processing Record 49 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 5 | arraial do cabo
# Processing Record 2 of Set 5 | sorong
# Processing Record 3 of Set 5 | liepaja
# Processing Record 4 of Set 5 | byron bay
# Processing Record 5 of Set 5 | tuatapere
# Processing Record 6 of Set 5 | esperance
# Processing Record 7 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 5 | aykhal
# Processing Record 9 of Set 5 | bathsheba
# Processing Record 10 of Set 5 | kazaki
# Processing Record 11 of Set 5 | columbus
# Processing Record 12 of Set 5 | myaundzha
# Processing Record 13 of Set 5 | umm kaddadah
# Processing Record 14 of Set 5 | daru
# Processing Record 15 of Set 5 | evensk
# Processing Record 16 of Set 5 | grand gaube
# Processing Record 17 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 5 | huilong
# Processing Record 19 of Set 5 | alfena
# Processing Record 20 of Set 5 | fort nelson
# Processing Record 21 of Set 5 | kisanga
# Processing Record 22 of Set 5 | naze
# Processing Record 23 of Set 5 | tiksi
# Processing Record 24 of Set 5 | ponta do sol
# Processing Record 25 of Set 5 | coahuayana
# Processing Record 26 of Set 5 | kahului
# Processing Record 27 of Set 5 | beringovskiy
# Processing Record 28 of Set 5 | padang
# Processing Record 29 of Set 5 | cidreira
# Processing Record 30 of Set 5 | faanui
# Processing Record 31 of Set 5 | barentu
# Processing Record 32 of Set 5 | boa vista
# Processing Record 33 of Set 5 | el alto
# Processing Record 34 of Set 5 | dudinka
# Processing Record 35 of Set 5 | barguzin
# Processing Record 36 of Set 5 | juneau
# Processing Record 37 of Set 5 | teyateyaneng
# Processing Record 38 of Set 5 | changli
# Processing Record 39 of Set 5 | praia
# Processing Record 40 of Set 5 | zambezi
# Processing Record 41 of Set 5 | tual
# Processing Record 42 of Set 5 | brae
# Processing Record 43 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 44 of Set 5 | north platte
# Processing Record 45 of Set 5 | shubarkuduk
# Processing Record 46 of Set 5 | pauini
# Processing Record 47 of Set 5 | mangalia
# Processing Record 48 of Set 5 | nyuksenitsa
# Processing Record 49 of Set 5 | port blair
# Processing Record 50 of Set 5 | bima
# Processing Record 1 of Set 6 | mar del plata
# Processing Record 2 of Set 6 | tula
# Processing Record 3 of Set 6 | dicabisagan
# Processing Record 4 of Set 6 | manavalakurichi
# Processing Record 5 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 6 | kant
# Processing Record 7 of Set 6 | xinyang
# Processing Record 8 of Set 6 | shima
# Processing Record 9 of Set 6 | upernavik
# Processing Record 10 of Set 6 | marawi
# Processing Record 11 of Set 6 | poitiers
# Processing Record 12 of Set 6 | hollabrunn
# Processing Record 13 of Set 6 | las choapas
# Processing Record 14 of Set 6 | victoria
# Processing Record 15 of Set 6 | yining
# Processing Record 16 of Set 6 | pangnirtung
# Processing Record 17 of Set 6 | paris
# Processing Record 18 of Set 6 | shiraoi
# Processing Record 19 of Set 6 | ribeira grande
# Processing Record 20 of Set 6 | torbay
# Processing Record 21 of Set 6 | polson
# Processing Record 22 of Set 6 | coihaique
# Processing Record 23 of Set 6 | aleksandrov gay
# Processing Record 24 of Set 6 | ola
# Processing Record 25 of Set 6 | sayhat
# Processing Record 26 of Set 6 | makakilo city
# Processing Record 27 of Set 6 | toamasina
# Processing Record 28 of Set 6 | saldanha
# Processing Record 29 of Set 6 | ciudad bolivar
# Processing Record 30 of Set 6 | turinsk
# Processing Record 31 of Set 6 | kieta
# Processing Record 32 of Set 6 | luganville
# Processing Record 33 of Set 6 | bintulu
# Processing Record 34 of Set 6 | hannibal
# Processing Record 35 of Set 6 | kruisfontein
# Processing Record 36 of Set 6 | dabakala
# Processing Record 37 of Set 6 | long xuyen
# Processing Record 38 of Set 6 | belaya gora
# Processing Record 39 of Set 6 | cherskiy
# Processing Record 40 of Set 6 | deputatskiy
# Processing Record 41 of Set 6 | dembi dolo
# Processing Record 42 of Set 6 | altay
# Processing Record 43 of Set 6 | ortakoy
# Processing Record 44 of Set 6 | yumen
# Processing Record 45 of Set 6 | tigil
# Processing Record 46 of Set 6 | galle
# Processing Record 47 of Set 6 | grand baie
# Processing Record 48 of Set 6 | waipawa
# Processing Record 49 of Set 6 | kokuy
# Processing Record 50 of Set 6 | baykit
# Processing Record 1 of Set 7 | inuvik
# Processing Record 2 of Set 7 | tyukhtet
# Processing Record 3 of Set 7 | pombas
# Processing Record 4 of Set 7 | ambon
# Processing Record 5 of Set 7 | sterlibashevo
# Processing Record 6 of Set 7 | rosetta
# Processing Record 7 of Set 7 | luanda
# Processing Record 8 of Set 7 | jurm
# Processing Record 9 of Set 7 | banda aceh
# Processing Record 10 of Set 7 | east london
# Processing Record 11 of Set 7 | vestmannaeyjar
# Processing Record 12 of Set 7 | sembe
# Processing Record 13 of Set 7 | kavieng
# Processing Record 14 of Set 7 | aitape
# Processing Record 15 of Set 7 | camacha
# Processing Record 16 of Set 7 | lompoc
# Processing Record 17 of Set 7 | urumqi
# Processing Record 18 of Set 7 | talcahuano
# Processing Record 19 of Set 7 | geraldton
# Processing Record 20 of Set 7 | tacoronte
# Processing Record 21 of Set 7 | sarkand
# Processing Record 22 of Set 7 | anloga
# Processing Record 23 of Set 7 | aklavik
# Processing Record 24 of Set 7 | arroyo
# Processing Record 25 of Set 7 | salalah
# Processing Record 26 of Set 7 | namtsy
# Processing Record 27 of Set 7 | yerbogachen
# Processing Record 28 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 7 | biratnagar
# Processing Record 30 of Set 7 | lavrentiya
# Processing Record 31 of Set 7 | sao joao do piaui
# Processing Record 32 of Set 7 | mana
# Processing Record 33 of Set 7 | severo-kurilsk
# Processing Record 34 of Set 7 | jaisalmer
# Processing Record 35 of Set 7 | ayia galini
# Processing Record 36 of Set 7 | moses lake
# Processing Record 37 of Set 7 | kaili
# Processing Record 38 of Set 7 | tanout
# Processing Record 39 of Set 7 | kloulklubed
# Processing Record 40 of Set 7 | doha
# Processing Record 41 of Set 7 | shache
# Processing Record 42 of Set 7 | roma
# Processing Record 43 of Set 7 | degtyarsk
# Processing Record 44 of Set 7 | te anau
# Processing Record 45 of Set 7 | russell
# Processing Record 46 of Set 7 | alyangula
# Processing Record 47 of Set 7 | lazaro cardenas
# Processing Record 48 of Set 7 | yar-sale
# Processing Record 49 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 7 | pecos
# Processing Record 1 of Set 8 | mooi river
# City not found. Skipping...
# Processing Record 2 of Set 8 | mehamn
# Processing Record 3 of Set 8 | jaque
# Processing Record 4 of Set 8 | sevierville
# Processing Record 5 of Set 8 | eucaliptus
# Processing Record 6 of Set 8 | cockburn town
# Processing Record 7 of Set 8 | tazovskiy
# Processing Record 8 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 8 | wencheng
# Processing Record 10 of Set 8 | nelson
# Processing Record 11 of Set 8 | nizhniy bestyakh
# Processing Record 12 of Set 8 | dingle
# Processing Record 13 of Set 8 | wahiawa
# Processing Record 14 of Set 8 | vao
# Processing Record 15 of Set 8 | kidal
# Processing Record 16 of Set 8 | fortuna
# Processing Record 17 of Set 8 | santander jimenez
# Processing Record 18 of Set 8 | yarmouth
# Processing Record 19 of Set 8 | taoudenni
# Processing Record 20 of Set 8 | bandarbeyla
# Processing Record 21 of Set 8 | corrientes
# Processing Record 22 of Set 8 | port lincoln
# Processing Record 23 of Set 8 | barra patuca
# Processing Record 24 of Set 8 | chokwe
# Processing Record 25 of Set 8 | shelburne
# Processing Record 26 of Set 8 | codrington
# Processing Record 27 of Set 8 | kenai
# Processing Record 28 of Set 8 | kaitangata
# Processing Record 29 of Set 8 | moerai
# Processing Record 30 of Set 8 | adrar
# Processing Record 31 of Set 8 | klaksvik
# Processing Record 32 of Set 8 | ilhabela
# Processing Record 33 of Set 8 | bethel
# Processing Record 34 of Set 8 | boysun
# Processing Record 35 of Set 8 | obigarm
# Processing Record 36 of Set 8 | kushmurun
# Processing Record 37 of Set 8 | ossora
# Processing Record 38 of Set 8 | pangody
# Processing Record 39 of Set 8 | ovsyanka
# Processing Record 40 of Set 8 | shebekino
# Processing Record 41 of Set 8 | san policarpo
# Processing Record 42 of Set 8 | boddam
# Processing Record 43 of Set 8 | snezhnogorsk
# Processing Record 44 of Set 8 | ribeira brava
# Processing Record 45 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 46 of Set 8 | pringsewu
# Processing Record 47 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 48 of Set 8 | potosi
# Processing Record 49 of Set 8 | khatanga
# Processing Record 50 of Set 8 | zhuozhou
# City not found. Skipping...
# Processing Record 1 of Set 9 | hastings
# Processing Record 2 of Set 9 | santa maria
# Processing Record 3 of Set 9 | abu kamal
# Processing Record 4 of Set 9 | akdepe
# Processing Record 5 of Set 9 | tomohon
# Processing Record 6 of Set 9 | amnat charoen
# Processing Record 7 of Set 9 | dunedin
# Processing Record 8 of Set 9 | bahia honda
# Processing Record 9 of Set 9 | kargil
# Processing Record 10 of Set 9 | takhtamygda
# Processing Record 11 of Set 9 | sao paulo de olivenca
# Processing Record 12 of Set 9 | skerries
# Processing Record 13 of Set 9 | abu samrah
# Processing Record 14 of Set 9 | sioux lookout
# Processing Record 15 of Set 9 | port pirie
# Processing Record 16 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 9 | nerchinskiy zavod
# Processing Record 18 of Set 9 | jibuti
# Processing Record 19 of Set 9 | haines junction
# Processing Record 20 of Set 9 | sao joao da barra
# Processing Record 21 of Set 9 | huntingdon
# Processing Record 22 of Set 9 | razdolinsk
# Processing Record 23 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 9 | severobaykalsk
# Processing Record 25 of Set 9 | tutoia
# Processing Record 26 of Set 9 | artyom
# Processing Record 27 of Set 9 | okandja
# City not found. Skipping...
# Processing Record 28 of Set 9 | pyskowice
# Processing Record 29 of Set 9 | oriximina
# Processing Record 30 of Set 9 | ahipara
# Processing Record 31 of Set 9 | pantai remis
# Processing Record 32 of Set 9 | dekar
# Processing Record 33 of Set 9 | carauari
# Processing Record 34 of Set 9 | limon
# Processing Record 35 of Set 9 | komsomolskiy
# Processing Record 36 of Set 9 | najran
# Processing Record 37 of Set 9 | swellendam
# Processing Record 38 of Set 9 | tarragona
# Processing Record 39 of Set 9 | umea
# Processing Record 40 of Set 9 | ornskoldsvik
# Processing Record 41 of Set 9 | barra do bugres
# Processing Record 42 of Set 9 | sari
# Processing Record 43 of Set 9 | mitzic
# Processing Record 44 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 9 | nanortalik
# Processing Record 46 of Set 9 | olga
# Processing Record 47 of Set 9 | narimanov
# Processing Record 48 of Set 9 | camana
# Processing Record 49 of Set 9 | auki
# Processing Record 50 of Set 9 | bardiyah
# Processing Record 1 of Set 10 | portland
# Processing Record 2 of Set 10 | jackson
# Processing Record 3 of Set 10 | sao felix do xingu
# Processing Record 4 of Set 10 | yaan
# Processing Record 5 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 6 of Set 10 | puerto del rosario
# Processing Record 7 of Set 10 | nizwa
# Processing Record 8 of Set 10 | rio gallegos
# Processing Record 9 of Set 10 | hirara
# Processing Record 10 of Set 10 | yokadouma
# Processing Record 11 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 12 of Set 10 | krasnoselkup
# Processing Record 13 of Set 10 | derecske
# Processing Record 14 of Set 10 | ternate
# Processing Record 15 of Set 10 | alindao
# Processing Record 16 of Set 10 | alugan
# Processing Record 17 of Set 10 | olovyannaya
# Processing Record 18 of Set 10 | kyabe
# Processing Record 19 of Set 10 | chimay
# Processing Record 20 of Set 10 | guerrero negro
# Processing Record 21 of Set 10 | flinders
# Processing Record 22 of Set 10 | tocopilla
# Processing Record 23 of Set 10 | charlottesville
# Processing Record 24 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 10 | harper
# Processing Record 26 of Set 10 | mabai
# Processing Record 27 of Set 10 | dali
# Processing Record 28 of Set 10 | messina
# Processing Record 29 of Set 10 | nagato
# Processing Record 30 of Set 10 | honningsvag
# Processing Record 31 of Set 10 | mount gambier
# Processing Record 32 of Set 10 | mangrol
# Processing Record 33 of Set 10 | smithers
# Processing Record 34 of Set 10 | xifeng
# Processing Record 35 of Set 10 | eenhana
# Processing Record 36 of Set 10 | nishihara
# Processing Record 37 of Set 10 | rurrenabaque
# Processing Record 38 of Set 10 | darhan
# Processing Record 39 of Set 10 | korla
# Processing Record 40 of Set 10 | mao
# Processing Record 41 of Set 10 | chum phae
# Processing Record 42 of Set 10 | izhma
# Processing Record 43 of Set 10 | kalmunai
# Processing Record 44 of Set 10 | suez
# Processing Record 45 of Set 10 | oranjemund
# Processing Record 46 of Set 10 | saint-francois
# Processing Record 47 of Set 10 | avera
# Processing Record 48 of Set 10 | leningradskiy
# Processing Record 49 of Set 10 | kudahuvadhoo
# Processing Record 50 of Set 10 | hofn
# Processing Record 1 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 2 of Set 11 | pacific grove
# Processing Record 3 of Set 11 | lasa
# Processing Record 4 of Set 11 | ancud
# Processing Record 5 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 6 of Set 11 | saltpond
# Processing Record 7 of Set 11 | ponta delgada
# Processing Record 8 of Set 11 | bongandanga
# Processing Record 9 of Set 11 | weligama
# Processing Record 10 of Set 11 | ife
# Processing Record 11 of Set 11 | faya
# Processing Record 12 of Set 11 | mirnyy
# Processing Record 13 of Set 11 | rumphi
# Processing Record 14 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 11 | wucheng
# Processing Record 16 of Set 11 | nouadhibou
# Processing Record 17 of Set 11 | sikasso
# Processing Record 18 of Set 11 | coquimbo
# Processing Record 19 of Set 11 | mier
# Processing Record 20 of Set 11 | high rock
# Processing Record 21 of Set 11 | newport
# Processing Record 22 of Set 11 | shebunino
# Processing Record 23 of Set 11 | mareeba
# Processing Record 24 of Set 11 | lakatoro
# Processing Record 25 of Set 11 | port hueneme
# Processing Record 26 of Set 11 | skrunda
# Processing Record 27 of Set 11 | amapa
# Processing Record 28 of Set 11 | teknaf
# Processing Record 29 of Set 11 | fondi
# Processing Record 30 of Set 11 | ngunguru
# Processing Record 31 of Set 11 | guatire
# Processing Record 32 of Set 11 | ushtobe
# Processing Record 33 of Set 11 | canakkale
# Processing Record 34 of Set 11 | mosquera
# Processing Record 35 of Set 11 | almeirim
# Processing Record 36 of Set 11 | trelew
# Processing Record 37 of Set 11 | augustow
# Processing Record 38 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 39 of Set 11 | moron
# Processing Record 40 of Set 11 | trincomalee
# Processing Record 41 of Set 11 | campo maior
# Processing Record 42 of Set 11 | tombouctou
# Processing Record 43 of Set 11 | along
# Processing Record 44 of Set 11 | catalina
# Processing Record 45 of Set 11 | hambantota
# Processing Record 46 of Set 11 | port arthur
# Processing Record 47 of Set 11 | mandera
# Processing Record 48 of Set 11 | rokiskis
# Processing Record 49 of Set 11 | sinnamary
# Processing Record 50 of Set 11 | inhambane
# Processing Record 1 of Set 12 | springbok
# Processing Record 2 of Set 12 | cardoso
# Processing Record 3 of Set 12 | port hawkesbury
# Processing Record 4 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 12 | vila velha
# Processing Record 6 of Set 12 | san patricio
# Processing Record 7 of Set 12 | bud
# Processing Record 8 of Set 12 | puerto madryn
# Processing Record 9 of Set 12 | wajima
# Processing Record 10 of Set 12 | lorengau
# Processing Record 11 of Set 12 | teguldet
# Processing Record 12 of Set 12 | trelleborg
# Processing Record 13 of Set 12 | bagdarin
# Processing Record 14 of Set 12 | marsa matruh
# Processing Record 15 of Set 12 | saint-augustin
# Processing Record 16 of Set 12 | tsiroanomandidy
# Processing Record 17 of Set 12 | catuday
# Processing Record 18 of Set 12 | mahon
# Processing Record 19 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 12 | mfou
# Processing Record 21 of Set 12 | lingao
# Processing Record 22 of Set 12 | prabumulih
# Processing Record 23 of Set 12 | shantipur
# Processing Record 24 of Set 12 | wajir
# Processing Record 25 of Set 12 | inverness
# Processing Record 26 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 12 | salinas
# Processing Record 28 of Set 12 | basco
# Processing Record 29 of Set 12 | payo
# Processing Record 30 of Set 12 | perth
# Processing Record 31 of Set 12 | bulgan
# Processing Record 32 of Set 12 | clyde river
# Processing Record 33 of Set 12 | popondetta
# Processing Record 34 of Set 12 | winslow
# Processing Record 35 of Set 12 | narsaq
# Processing Record 36 of Set 12 | phan thiet
# Processing Record 37 of Set 12 | palmas
# Processing Record 38 of Set 12 | mumford
# Processing Record 39 of Set 12 | woodward
# Processing Record 40 of Set 12 | karratha
# Processing Record 41 of Set 12 | santa catarina pinula
# Processing Record 42 of Set 12 | zhezkazgan
# Processing Record 43 of Set 12 | sakakah
# Processing Record 44 of Set 12 | eidfjord
# Processing Record 45 of Set 12 | mokhsogollokh
# Processing Record 46 of Set 12 | iquique
# Processing Record 47 of Set 12 | saint-raymond
# Processing Record 48 of Set 12 | ondjiva
# Processing Record 49 of Set 12 | victor harbor
# Processing Record 50 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 13 | cabo san lucas
# Processing Record 2 of Set 13 | batticaloa
# Processing Record 3 of Set 13 | port shepstone
# Processing Record 4 of Set 13 | thinadhoo
# Processing Record 5 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 13 | waingapu
# Processing Record 7 of Set 13 | mbekenyera
# Processing Record 8 of Set 13 | nara
# Processing Record 9 of Set 13 | virginia beach
# Processing Record 10 of Set 13 | williams lake
# Processing Record 11 of Set 13 | san jose
# Processing Record 12 of Set 13 | nome
# Processing Record 13 of Set 13 | marzuq
# Processing Record 14 of Set 13 | copiapo
# Processing Record 15 of Set 13 | tripoli
# Processing Record 16 of Set 13 | horasan
# Processing Record 17 of Set 13 | rubiataba
# Processing Record 18 of Set 13 | port macquarie
# Processing Record 19 of Set 13 | orlik
# Processing Record 20 of Set 13 | asau
# Processing Record 21 of Set 13 | qasigiannguit
# Processing Record 22 of Set 13 | tevaitoa
# Processing Record 23 of Set 13 | anshun
# Processing Record 24 of Set 13 | eufaula
# Processing Record 25 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 13 | sikonge
# Processing Record 27 of Set 13 | ambositra
# Processing Record 28 of Set 13 | lodja
# Processing Record 29 of Set 13 | hovd
# Processing Record 30 of Set 13 | illescas
# Processing Record 31 of Set 13 | tanete
# Processing Record 32 of Set 13 | la ligua
# Processing Record 33 of Set 13 | boyuibe
# Processing Record 34 of Set 13 | mkushi
# Processing Record 35 of Set 13 | antalaha
# Processing Record 36 of Set 13 | sindor
# Processing Record 37 of Set 13 | karpathos
# Processing Record 38 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 39 of Set 13 | kuznechikha
# Processing Record 40 of Set 13 | hun
# Processing Record 41 of Set 13 | shingu
# Processing Record 42 of Set 13 | noumea
# Processing Record 43 of Set 13 | rapina
# Processing Record 44 of Set 13 | do rud
# City not found. Skipping...
# Processing Record 45 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 13 | rio grande
# Processing Record 47 of Set 13 | samarai
# Processing Record 48 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 49 of Set 13 | teneguiban
# City not found. Skipping...
# Processing Record 50 of Set 13 | ilebo
# Processing Record 1 of Set 14 | jermuk
# Processing Record 2 of Set 14 | nanpiao
# Processing Record 3 of Set 14 | lagunas
# Processing Record 4 of Set 14 | panji
# Processing Record 5 of Set 14 | kousseri
# Processing Record 6 of Set 14 | tura
# Processing Record 7 of Set 14 | southbridge
# Processing Record 8 of Set 14 | ilulissat
# Processing Record 9 of Set 14 | mount isa
# Processing Record 10 of Set 14 | porto velho
# Processing Record 11 of Set 14 | white rock
# Processing Record 12 of Set 14 | porto novo
# Processing Record 13 of Set 14 | emerald
# Processing Record 14 of Set 14 | lucapa
# Processing Record 15 of Set 14 | la reforma
# Processing Record 16 of Set 14 | savannah bight
# Processing Record 17 of Set 14 | lata
# Processing Record 18 of Set 14 | banepa
# Processing Record 19 of Set 14 | moundou
# Processing Record 20 of Set 14 | tatarsk
# Processing Record 21 of Set 14 | road town
# Processing Record 22 of Set 14 | dezful
# Processing Record 23 of Set 14 | itarema
# Processing Record 24 of Set 14 | mingshui
# Processing Record 25 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 26 of Set 14 | roura
# Processing Record 27 of Set 14 | rocky mount
# Processing Record 28 of Set 14 | paita
# Processing Record 29 of Set 14 | nakamura
# Processing Record 30 of Set 14 | osmena
# Processing Record 31 of Set 14 | pontianak
# Processing Record 32 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 14 | ambunti
# Processing Record 34 of Set 14 | naliya
# Processing Record 35 of Set 14 | oussouye
# Processing Record 36 of Set 14 | voskresenskoye
# Processing Record 37 of Set 14 | kapuskasing
# Processing Record 38 of Set 14 | xinzhou
# Processing Record 39 of Set 14 | canton
# Processing Record 40 of Set 14 | guaimaca
# Processing Record 41 of Set 14 | novoagansk
# Processing Record 42 of Set 14 | indaiatuba
# Processing Record 43 of Set 14 | chara
# Processing Record 44 of Set 14 | amzya
# Processing Record 45 of Set 14 | toowoomba
# Processing Record 46 of Set 14 | sitka
# Processing Record 47 of Set 14 | iquitos
# Processing Record 48 of Set 14 | kanker
# Processing Record 49 of Set 14 | jasper
# Processing Record 50 of Set 14 | ko samui
# Processing Record 1 of Set 15 | mazagao
# Processing Record 2 of Set 15 | arys
# Processing Record 3 of Set 15 | buchanan
# Processing Record 4 of Set 15 | vaitape
# Processing Record 5 of Set 15 | okitipupa
# Processing Record 6 of Set 15 | caucaia
# Processing Record 7 of Set 15 | wellingborough
# Processing Record 8 of Set 15 | martapura
# Processing Record 9 of Set 15 | high prairie
# Processing Record 10 of Set 15 | yenagoa
# Processing Record 11 of Set 15 | belmonte
# Processing Record 12 of Set 15 | litovko
# Processing Record 13 of Set 15 | suihua
# Processing Record 14 of Set 15 | zaozhuang
# Processing Record 15 of Set 15 | dedovichi
# Processing Record 16 of Set 15 | mogzon
# Processing Record 17 of Set 15 | saint-joseph
# Processing Record 18 of Set 15 | puerto escondido
# Processing Record 19 of Set 15 | trinidad
# Processing Record 20 of Set 15 | teya
# Processing Record 21 of Set 15 | bam
# Processing Record 22 of Set 15 | bilibino
# Processing Record 23 of Set 15 | chemodanovka
# Processing Record 24 of Set 15 | walvis bay
# Processing Record 25 of Set 15 | rawson
# Processing Record 26 of Set 15 | rorvik
# Processing Record 27 of Set 15 | youghal
# Processing Record 28 of Set 15 | porto-vecchio
# Processing Record 29 of Set 15 | caravelas
# Processing Record 30 of Set 15 | vityazevo
# Processing Record 31 of Set 15 | togur
# Processing Record 32 of Set 15 | prince albert
# Processing Record 33 of Set 15 | dwarka
# Processing Record 34 of Set 15 | onguday
# Processing Record 35 of Set 15 | okhtyrka
# Processing Record 36 of Set 15 | bo
# City not found. Skipping...
# Processing Record 37 of Set 15 | lagoa
# Processing Record 38 of Set 15 | kroonstad
# Processing Record 39 of Set 15 | opuwo
# Processing Record 40 of Set 15 | muros
# Processing Record 41 of Set 15 | soyo
# Processing Record 42 of Set 15 | alofi
# Processing Record 43 of Set 15 | springfield
# Processing Record 44 of Set 15 | tres arroyos
# Processing Record 45 of Set 15 | riyadh
# Processing Record 46 of Set 15 | povenets
# Processing Record 47 of Set 15 | campbell river
# Processing Record 48 of Set 15 | minab
# Processing Record 49 of Set 15 | victoria point
# Processing Record 50 of Set 15 | slantsy
# Processing Record 1 of Set 16 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 2 of Set 16 | wanning
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0       Saskylakh      RU  2021-11-01 04:39:00  71.9167  114.0833      2.32
# 1     Tuktoyaktuk      CA  2021-11-01 04:39:01  69.4541 -133.0374     30.20
# 2        Hermanus      ZA  2021-11-01 04:39:01 -34.4187   19.2345     61.81
# 3          Atuona      PF  2021-11-01 04:35:20  -9.8000 -139.0333     78.84
# 4    Punta Arenas      CL  2021-11-01 04:39:02 -53.1500  -70.9167     46.51
# 5       Busselton      AU  2021-11-01 04:39:03 -33.6500  115.3333     63.05
# 6        Ahuimanu      US  2021-11-01 04:39:04  21.4447 -157.8378     80.31
# 7  Port Elizabeth      ZA  2021-11-01 04:39:04 -33.9180   25.5701     64.09
# 8         Qaanaaq      GL  2021-11-01 04:37:53  77.4840  -69.3632     19.27
# 9        Thompson      CA  2021-11-01 04:39:05  55.7435  -97.8558     26.76
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        97          97        5.21     overcast clouds
# 1        80          75       14.97       broken clouds
# 2        74          93       13.80          light rain
# 3        73           0       18.92           clear sky
# 4        57           0        8.05           clear sky
# 5        52          82       20.92       broken clouds
# 6        71          90        4.61     overcast clouds
# 7        88          20       20.71          few clouds
# 8        91         100        7.70     overcast clouds
# 9        80          75       10.36       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
